# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip3 install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already up-to-date: getorg in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (0.3.1)
# Requirement already satisfied, skipping upgrade: geopy in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from getorg) (1.21.0)
# Requirement already satisfied, skipping upgrade: retrying in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from getorg) (1.3.3)
# Requirement already satisfied, skipping upgrade: pygithub in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from getorg) (1.47)
# Requirement already satisfied, skipping upgrade: geographiclib<2,>=1.49 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from geopy->getorg) (1.50)
# Requirement already satisfied, skipping upgrade: six>=1.7.0 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from retrying->getorg) (1.14.0)
# Requirement already satisfied, skipping upgrade: pyjwt in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from pygithub->getorg) (1.7.1)
# Requirement already satisfied, skipping upgrade: requests>=2.14.0 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from pygithub->getorg) (2.23.0)
# Requirement already satisfied, skipping upgrade: deprecated in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from pygithub->getorg) (1.2.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (1.25.9)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (2.9)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in /Users/lmoncla/.pyenv/versions/3.7.3/lib/python3.7/site-packages (from deprecated->pygithub->getorg) (1.12.1)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f991685e0e5c> in <module>()
#       1 get_ipython().system('pip3 install getorg --upgrade')
#       2 import glob
# ----> 3 import getorg
#       4 from geopy import Nominatim
#
# ModuleNotFoundError: No module named 'getorg'

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Berkeley CA, USA
#  Berkeley, Alameda County, California, United States of America
# Los Angeles, CA
#  LA, Los Angeles County, California, United States of America
# London, UK
#  London, Greater London, England, UK
# San Francisco, California
#  SF, California, United States of America

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
